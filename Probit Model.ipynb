# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
from matplotlib.pyplot import figure
import statsmodels.api as smf

# %%
aggregated_tech_df = pd.read_csv('C:/Users/jakob/Desktop/Code Seminar Strategy Mining/dataframes/aggregated_tech_df.csv')
aggregated_unit_df = pd.read_csv('C:/Users/jakob/Desktop/Code Seminar Strategy Mining/dataframes/aggregated_unit_df.csv')
aggregated_building_df = pd.read_csv('C:/Users/jakob/Desktop/Code Seminar Strategy Mining/dataframes/aggregated_building_df.csv')
aggregated_building_unit_tech_df = pd.read_csv('C:/Users/jakob/Desktop/Code Seminar Strategy Mining/dataframes/aggregated_building_unit_tech_df.csv')

# %%
plt.rc("font", size=14)
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
df1=aggregated_unit_df.drop(['file_num','Match_ID'],axis=1)
figure(figsize=(8, 6), dpi=80)
df1.corr()
corr_matrix = df1.corr()
sns.heatmap(corr_matrix, annot=True,vmin=-1, vmax=1)
plt.show()

# %%
y=aggregated_unit_df['Winner']
x_cols=['Ranged Units', 'Melee Units', 'Cavalry Units', 'Siege Units', 'Other Units']
X=aggregated_unit_df[x_cols]
probit_model=smf.Probit(y,X)
result=probit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.689349
#          Iterations 4
#                          Results: Probit
# ...
# Model:              Probit           Method:           MLE
# Dependent Variable: Winner           Pseudo R-squared: 0.005
# Date:               2023-06-30 18:18 AIC:              13508.8356
# No. Observations:   9791             BIC:              13544.7817
# Df Model:           4                Log-Likelihood:   -6749.4
# Df Residuals:       9786             LL-Null:          -6786.1
# Converged:          1.0000           LLR p-value:      4.3182e-15
# No. Iterations:     4.0000           Scale:            1.0000
# -----------------------------------------------------------------
#                    Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------
# Ranged Units       0.0011   0.0003  3.1355 0.0017  0.0004  0.0018
# ...

# %%
aggregated_building_unit_tech_df=aggregated_building_unit_tech_df.drop(['file_num','Match_ID'],axis=1)
aggregated_building_unit_tech_df.corr()
# Out:
#                       Winner  Economic Building  Research Building  \
# Winner              1.000000          -0.062759          -0.045520
# Economic Building  -0.062759           1.000000           0.569577
# Research Building  -0.045520           0.569577           1.000000
# Defensive Building -0.037779           0.507907           0.383400
# Military Building  -0.044400           0.721946           0.535144
# Other Building     -0.054434           0.689785           0.553653
# Ranged Units        0.015209           0.210143           0.192337
# Melee Units         0.003509           0.182873           0.114669
# Cavalry Units       0.005855           0.259449           0.145800
# Siege Units        -0.013095           0.215967           0.166985
# Other Units        -0.009277           0.394637           0.273299
# Building Tech      -0.028722           0.115535           0.076394
# Economy Tech       -0.031493           0.138662           0.089581
# ...

# %%
figure(figsize=(8, 6), dpi=80)
aggregated_building_unit_tech_df.corr()
corr_matrix = aggregated_building_unit_tech_df.corr()
sns.heatmap(corr_matrix, annot=False,vmin=-1, vmax=1)
plt.show()

# %%
y=aggregated_building_unit_tech_df['Winner']
x_cols=['Economic Building','Research Building','Defensive Building','Military Building','Other Building','Ranged Units', 'Melee Units', 'Cavalry Units', 'Siege Units', 'Other Units','Building Tech','Economy Tech','Monastery Tech','Infantery Tech','Missile-Siege Tech','Cavalry Tech','Dock Tech','Other Tech', 'Age Tech']
X=aggregated_building_unit_tech_df[x_cols]
probit_model=smf.Probit(y,X)
result=probit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.689623
#          Iterations 4
#                          Results: Probit
# ...
# Model:               Probit           Method:           MLE
# Dependent Variable:  Winner           Pseudo R-squared: 0.005
# Date:                2023-06-30 18:19 AIC:              13554.6121
# No. Observations:    9800             BIC:              13691.2247
# Df Model:            18               Log-Likelihood:   -6758.3
# Df Residuals:        9781             LL-Null:          -6792.4
# Converged:           1.0000           LLR p-value:      9.3311e-08
# No. Iterations:      4.0000           Scale:            1.0000
# ------------------------------------------------------------------
#                     Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Economic Building  -0.0023   0.0008 -2.8293 0.0047 -0.0039 -0.0007
# ...

# %%
aggregated_building_df.corr()
# Out:
#                     file_num  Match_ID    Winner  Economic Building  \
# file_num            1.000000  1.000000 -0.006466          -0.058335
# Match_ID            1.000000  1.000000 -0.006465          -0.058335
# Winner             -0.006466 -0.006465  1.000000          -0.062759
# Economic Building  -0.058335 -0.058335 -0.062759           1.000000
# Research Building  -0.044756 -0.044754 -0.045520           0.569577
# Defensive Building -0.009760 -0.009760 -0.037779           0.507907
# Military Building  -0.059961 -0.059960 -0.044400           0.721946
# Other Building     -0.059679 -0.059681 -0.054434           0.689785
#
#                     Research Building  Defensive Building  Military Building  \
# file_num                    -0.044756           -0.009760          -0.059961
# Match_ID                    -0.044754           -0.009760          -0.059960
# Winner                      -0.045520           -0.037779          -0.044400
# ...

# %%
aggregated_building_df = aggregated_building_df.drop(['file_num','Match_ID'],axis=1)

figure(figsize=(8, 6), dpi=80)
aggregated_building_df.corr()
corr_matrix = aggregated_building_df.corr()
sns.heatmap(corr_matrix, annot=True,vmin=-1, vmax=1)
plt.show()

# %%
aggregated_tech_df = aggregated_tech_df.drop(['file_num','Match_ID'],axis=1)


aggregated_tech_df.corr()
figure(figsize=(8, 6), dpi=80)
aggregated_tech_df.corr()
corr_matrix = aggregated_tech_df.corr()
sns.heatmap(corr_matrix, annot=True,vmin=-1, vmax=1)
plt.show()
